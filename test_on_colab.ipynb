# %%
{
  "cells": [
    {
      "cell_type": "markdown",
      "metadata": {
        "id": "view-in-github"
      },
      "source": [
        "# Iris Classification System - CUDA Implementation Test\n",
        "\n",
        "This notebook tests the CUDA-based Iris Classification System on Google Colab's GPU environment."
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "check-gpu"
      },
      "source": [
        "# Check GPU availability\n",
        "!nvidia-smi"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "clone-repository"
      },
      "source": [
        "# Clone the repository\n",
        "!git clone https://github.com/YOUR_USERNAME/REPOSITORY_NAME.git\n",
        "%cd REPOSITORY_NAME"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "install-dependencies"
      },
      "source": [
        "# Install required packages\n",
        "!pip install numpy pandas matplotlib seaborn"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "build-project"
      },
      "source": [
        "# Make scripts executable\n",
        "!chmod +x install.sh run.sh\n",
        "\n",
        "# Run installation script\n",
        "!./install.sh"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "run-tests"
      },
      "source": [
        "# Run the project\n",
        "!./run.sh"
      ]
    },
    {
      "cell_type": "code",
      "metadata": {
        "id": "display-results"
      },
      "source": [
        "# Display results\n",
        "import matplotlib.pyplot as plt\n",
        "import matplotlib.image as mpimg\n",
        "\n",
        "# Display performance plots\n",
        "plt.figure(figsize=(15, 5))\n",
        "\n",
        "plt.subplot(1, 3, 1)\n",
        "img = mpimg.imread('results/accuracy_metrics.png')\n",
        "plt.imshow(img)\n",
        "plt.axis('off')\n",
        "plt.title('Accuracy Metrics')\n",
        "\n",
        "plt.subplot(1, 3, 2)\n",
        "img = mpimg.imread('results/performance_metrics.png')\n",
        "plt.imshow(img)\n",
        "plt.axis('off')\n",
        "plt.title('Performance Metrics')\n",
        "\n",
        "plt.subplot(1, 3, 3)\n",
        "img = mpimg.imread('results/precision_recall.png')\n",
        "plt.imshow(img)\n",
        "plt.axis('off')\n",
        "plt.title('Precision-Recall')\n",
        "\n",
        "plt.tight_layout()\n",
        "plt.show()\n",
        "\n",
        "# Display summary report\n",
        "print('\\nSummary Report:')\n",
        "print('=' * 50)\n",
        "with open('results/summary_report.txt', 'r') as f:\n",
        "    print(f.read())"
      ]
    }
  ],
  "metadata": {
    "accelerator": "GPU",
    "colab": {
      "name": "Iris_Classification_CUDA_Test.ipynb",
      "provenance": []
    },
    "kernelspec": {
      "display_name": "Python 3",
      "name": "python3"
    }
  },
  "nbformat": 4,
  "nbformat_minor": 0
}
